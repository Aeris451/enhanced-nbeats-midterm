# %%
import os
import sys
import numpy as np
import pandas as pd
import tensorflow as tf
from typing import Dict, NamedTuple, Union
import logging
from matplotlib import pyplot as plt
import time
from itertools import product
import gc
import pathlib
from glob import glob
from dateutil.relativedelta import relativedelta
from tqdm import tqdm 
import os
import json

# %%
class Parameters(NamedTuple):
    split: int
    repeat: int
    epochs: int
    steps_per_epoch: int
    block_layers: int
    hidden_units: int
    num_blocks: int
    block_sharing: bool
    horizon: int
    history_lookback: int
    init_learning_rate: float
    decay_steps: int
    decay_rate: float
    loss: str
    pinball_tau: float
    nmse_weight: float
    pnmse_weights: str
    batch_size: int
    weight_decay: float
    ts_sampling: str



hyperparams_dict = {
    "split": 0, # 0 is test split, 1 is validation split
    "repeat": list(range(0, 1024)), 
    "epochs": 20, 
    "steps_per_epoch": [100], 
    "block_layers": [3],
    "hidden_units": 512,
    "num_blocks": 6,
    "block_sharing": True, # [True, False]
    "horizon": 12,
    "history_lookback": 1,
    "init_learning_rate": 1e-3,
    "decay_steps": 3,
    "decay_rate": 0.5,
    "loss": ["pnmse"],  # ["pnmse", "pinball", "mape", "smape", "pmape", "rmse"]
    "pnmse_weights": ["mape"], # ["mape", "smape"]
    "pinball_tau": [0.35], # This is selected to minimize the bias on the validation set
    "nmse_weight": [0.35],
    "batch_size": 256,
    "weight_decay": 0,
    "ts_sampling": ["ts_weight"], # ["uniform", "ts_weight"]
}

HORIZON = 12

hyperparams = Parameters(**hyperparams_dict)

# %%
class ElectricityLoader:
    def __init__(self, path="data/", split='train'):
        self.path = path
        self.split = split
        ts_raw = pd.read_csv(os.path.join(path,f'Electricity-{split}.csv')).iloc[:,1:].values.astype(np.float32)
        self.ts_raw = []
        
        for ts in ts_raw:
            self.ts_raw.append(ts[~np.isnan(ts)])

        self.ts_weight = np.zeros((len(self.ts_raw),), dtype=np.float32)
        for i,ts in enumerate(self.ts_raw):
            self.ts_weight[i] = len(ts)
        self.ts_weight = self.ts_weight / self.ts_weight.sum()

    def get_val_split(self, split_horizon=1):
        train_dataset = ElectricityLoader(path=self.path, split='train')
        test_dataset = ElectricityLoader(path=self.path, split='train')
        ts_raw = []
        for ts in train_dataset.ts_raw:
            ts_raw.append(ts[:-split_horizon*12])
        train_dataset.ts_raw = ts_raw
        ts_raw = []
        for ts in test_dataset.ts_raw:
            ts_raw.append(ts[-split_horizon*12:])
        test_dataset.ts_raw = ts_raw
        return train_dataset, test_dataset

    def get_batch(self, batch_size=64, win_len=14*2, horizon=12, ts_sampling='uniform'):
        target_ts = np.zeros((batch_size, horizon), dtype=np.float32)
        history_ts = np.zeros((batch_size, win_len), dtype=np.float32)

        if ts_sampling == "uniform":
            ts_idxs = np.random.choice(np.arange(len(self.ts_raw)), size=batch_size, replace=True)
        elif ts_sampling == "ts_weight":
            ts_idxs = np.random.choice(np.arange(len(self.ts_raw)), size=batch_size, replace=True, p=self.ts_weight)
            
        for i, ts_id in enumerate(ts_idxs):
            ts = self.ts_raw[ts_id]
            sampling_point = np.random.choice(np.arange(win_len, len(ts)-horizon+1), size=1, replace=False)[0]
            history_ts[i,:] = ts[sampling_point-win_len:sampling_point]
            target_ts[i,:] = ts[sampling_point:sampling_point+horizon]

        batch = {"history": history_ts, "target": target_ts}
        return batch


    def get_sequential_batch(self, win_len=14*2):
        history_ts = np.zeros((len(self.ts_raw), win_len), dtype=np.float32)
        for i, ts in enumerate(self.ts_raw):
            history_ts[i,:] = ts[-win_len:]
        return {"history": history_ts}

# %%
class NBeatsBlock(tf.keras.layers.Layer):
        def __init__(self, hyperparams: Parameters, input_size:int, output_size:int, **kw):
            super(NBeatsBlock, self).__init__(**kw)
            self.hyperparams = hyperparams
            self.input_size = input_size
            self.output_size = output_size
            self.fc_layers = []
            for i in range(hyperparams.block_layers):
                self.fc_layers.append(
                    tf.keras.layers.Dense(hyperparams.hidden_units,
                                        activation=tf.nn.relu,
                                        kernel_regularizer=tf.keras.regularizers.l2(hyperparams.weight_decay),
                                        name=f"fc_{i}")
                )
            self.forecast = tf.keras.layers.Dense(output_size, activation=None, name="forecast")
            self.backcast = tf.keras.layers.Dense(self.input_size, activation=None, name="backcast")

        def call(self, inputs, training=False):
            epsilon = 1e-6 

            h = self.fc_layers[0](inputs)
            for i in range(1, self.hyperparams.block_layers):
                h = self.fc_layers[i](h)
            backcast = self.backcast(h)



            mu = tf.reduce_mean(inputs, axis=-1, keepdims=True)
            std = tf.math.reduce_std(inputs, axis=-1, keepdims=True)
            std = tf.maximum(std, epsilon)  # Prevent std from being too small

            backcast = backcast * std + mu
            backcast = tf.keras.activations.relu(inputs - backcast)

            forecast = self.forecast(h)
            forecast = forecast * std + mu
            return backcast, forecast

# %%
class NBeats:
    def __init__(self, hyperparams: Parameters, name: str='NBeats', logdir: str='logs', num_nodes: int = 100):
        super(NBeats, self).__init__()
        self.hyperparams = hyperparams
        self.name = name
        self.logdir = logdir
        self.num_nodes = num_nodes
        self.input_size = self.hyperparams.history_lookback * self.hyperparams.horizon

        self.nbeats_layers = []
        self.nbeats_layers.append(NBeatsBlock(hyperparams=hyperparams,
                                              input_size=self.input_size,
                                              output_size=hyperparams.horizon,
                                              name=f"nbeats_{0}")
                                  )
        for i in range(1, hyperparams.num_blocks):
            if self.hyperparams.block_sharing:
                self.nbeats_layers.append(self.nbeats_layers[0])
            else:
                self.nbeats_layers.append(NBeatsBlock(hyperparams=hyperparams,
                                                      input_size=self.input_size,
                                                      output_size=hyperparams.horizon,
                                                      name=f"nbeats_{i}")
                                          )

        inputs, outputs = self.get_model()
        model = tf.keras.Model(inputs=inputs, outputs=outputs, name=name)
        self.inputs = inputs
        self.outputs = outputs
        self.model = model

    def get_model(self):
        history_in = tf.keras.layers.Input(shape=(self.hyperparams.history_lookback * self.hyperparams.horizon,), name='history')

        level = tf.keras.layers.Lambda(lambda x: tf.reduce_max(x, axis=-1, keepdims=True))(history_in)
        history_delevel = tf.keras.layers.Lambda(lambda x: tf.math.divide_no_nan(x[0], x[1]))([history_in, level])

        backcast, forecast = self.nbeats_layers[0](inputs=history_delevel)
        for nb in self.nbeats_layers[1:]:
            backcast, forecast_layer = nb(inputs=backcast)
            forecast = tf.keras.layers.Add()([forecast, forecast_layer])

        forecast = tf.keras.layers.Multiply()([forecast, level])

        inputs = {'history': history_in}
        outputs = {'target': forecast}
        return inputs, outputs

    def forecast(self, train_dataset):
        input_data = train_dataset.get_sequential_batch(win_len=self.hyperparams.horizon * self.hyperparams.history_lookback)
        return self.model.predict({"history": input_data["history"]})['target']

# %%
def smape(labels, preds):
    weights = tf.stop_gradient(
        tf.math.divide_no_nan(2.0, (tf.abs(preds) + tf.abs(labels))))
    return tf.reduce_mean(tf.abs(preds - labels) * weights)

def mape(labels, preds):
    weights = tf.math.divide_no_nan(1.0, tf.abs(labels))
    return tf.reduce_mean(tf.abs(preds - labels) * weights)

def get_pmape_loss(tau):
    def pmape_loss(labels, preds):
        weights = tf.math.divide_no_nan(1.0, tf.abs(labels))
        pinball = tf.where(labels > preds,
                           x=tau*(labels - preds), 
                           y=(1-tau)*(preds-labels))
        return tf.reduce_mean(pinball * weights)
    return pmape_loss

def get_pinball_loss(tau):
    def pinball_loss(labels, preds):
        pinball = tf.where(labels > preds,
                           x=tau*(labels - preds), 
                           y=(1-tau)*(preds-labels))
        return tf.reduce_mean(pinball)
    return pinball_loss

def mae(labels, preds):
    return tf.reduce_mean(tf.abs(preds - labels))

def rmse(labels, preds):
    rmse_values = tf.sqrt(tf.reduce_mean(tf.square(preds - labels), axis=1))
    return tf.reduce_mean(rmse_values)





def get_pnmse(tau, nmse_weight, weights):
    def pnmse_loss(labels, preds):    


        pinball = tf.where(labels > preds,
                           x=tau * (labels - preds), 
                           y=(1 - tau) * (preds - labels))
        pinball_loss = tf.reduce_mean(pinball * weights(labels, preds))
        
        variance = tf.math.reduce_variance(labels, axis=0)
        nmse = tf.reduce_mean(tf.square(preds - labels) / (variance + 1e-6))
        
        return pinball_loss + nmse_weight * nmse
    return pnmse_loss


def smape_weights(labels, preds):
    return tf.stop_gradient( tf.math.divide_no_nan(2.0, (tf.abs(preds) + tf.abs(labels))))


def mape_weights(labels, preds):
    return tf.math.divide_no_nan(1.0, tf.abs(labels))


class MetricsCallback(tf.keras.callbacks.Callback):
    def __init__(self, train_dataset, test_dataset, hyperparams):
        super().__init__()
        self.input_data = train_dataset.get_sequential_batch(win_len=hyperparams.horizon*hyperparams.history_lookback)
        self.target = np.array(test_dataset.ts_raw)

    def on_train_begin(self, logs={}):
        pass    

    def on_epoch_end(self, epoch, logs={}):
        prediction_test = self.model.predict({"history": self.input_data["history"]})
        logs['smape_test'] = smape(preds=prediction_test['target'], labels=self.target)
        logs['mape_test'] = mape(preds=prediction_test['target'], labels=self.target)

class Trainer:
    def __init__(self, hyperparams: Parameters, logdir: str):
        inp = dict(hyperparams._asdict())
        values = [v if isinstance(v, list) else [v] for v in inp.values()]
        self.hyperparams = [Parameters(**dict(zip(inp.keys(), v))) for v in product(*values)]
        inp_lists = {k: v  for k, v in inp.items() if isinstance(v, list)}
        values = [v for v in inp_lists.values()]
        variable_values = [dict(zip(inp_lists.keys(), v)) for v in product(*values)]
        folder_names = []
        for d in variable_values: 
            folder_names.append(
                ';'.join(['%s=%s' % (key, value) for (key, value) in d.items()])
            )
        self.history = []
        self.forecasts = []
        self.models = []
        self.logdir = logdir
        self.folder_names = folder_names
        for i, h in enumerate(self.hyperparams): 
            self.models.append(NBeats(hyperparams=h, name=f"nbeats_model_{i}", 
                                      logdir=os.path.join(self.logdir, folder_names[i])))
            
    def generator(self, ds, hyperparams: Parameters):
        while True:
            batch = ds.get_batch(batch_size=hyperparams.batch_size, 
                                 win_len=hyperparams.horizon*hyperparams.history_lookback, 
                                 horizon=hyperparams.horizon,
                                 ts_sampling=hyperparams.ts_sampling)

            yield  {"history": batch["history"]}, {"target": batch["target"]}

    def save_forecast(self, forecast: np.ndarray, filename: str = "forecast.npy"):
        np.save(f"{WORKING_PATH}/{filename}", forecast)
                            
    def fit(self, train_dataset, test_dataset, verbose=1):
        for i, hyperparams in enumerate(self.hyperparams):
            if verbose > 0:
                print(f"Fitting model {i+1} out of {len(self.hyperparams)}, {self.folder_names[i]}")

            path = f"results/{MODEL_VERSION}_split{self.models[i].hyperparams.split}/"
            pathlib.Path(f"{WORKING_PATH}/{path}").mkdir(parents=True, exist_ok=True)
            filename = os.path.join(path, self.folder_names[i]+'.npy')
            if os.path.exists(f"{WORKING_PATH}/{filename}"):
                continue
            
            boundary_step = hyperparams.epochs // 10
            boundary_start = hyperparams.epochs - boundary_step * hyperparams.decay_steps - 1

            boundaries = list(range(boundary_start, hyperparams.epochs, boundary_step))
            values = [float(hyperparams.init_learning_rate * hyperparams.decay_rate ** i) for i in range(len(boundaries) + 1)]
            
            def scheduler(epoch, lr):
                index = np.searchsorted(boundaries, epoch, side='right')
                return float(values[index])

            lr = tf.keras.callbacks.LearningRateScheduler(scheduler, verbose=0)

            metrics = MetricsCallback(train_dataset=train_dataset, test_dataset=test_dataset, hyperparams=hyperparams)
            # tb = tf.keras.callbacks.TensorBoard(log_dir=self.models[i].logdir, embeddings_freq=10)

            if hyperparams.loss == 'smape':
                loss = smape
            elif hyperparams.loss == 'mape':
                loss = mape
            elif hyperparams.loss == 'mae':
                loss = mae
            elif hyperparams.loss == 'rmse':
                loss = rmse
            elif hyperparams.loss == 'pmape':
                loss = get_pmape_loss(hyperparams.pinball_tau)
            elif hyperparams.loss == 'pinball':
                loss = get_pinball_loss(hyperparams.pinball_tau)
            elif hyperparams.loss == 'pnmse':
                if hyperparams.pnmse_weights == 'smape':
                    loss = get_pnmse(hyperparams.pinball_tau, hyperparams.nmse_weight, smape_weights)
                elif hyperparams.pnmse_weights == 'mape':
                    loss = get_pnmse(hyperparams.pinball_tau, hyperparams.nmse_weight, mape_weights)
                else:
                    raise ValueError(f"Unknown pnmse weights function: {hyperparams.pnmse_weights}")
            else:
                raise ValueError(f"Unknown loss function: {hyperparams.loss}")
            
            self.models[i].model.compile(optimizer=tf.keras.optimizers.Adam(),
                                        loss=loss)

            fit_output = self.models[i].model.fit(self.generator(ds=train_dataset, hyperparams=hyperparams),
                                                callbacks=[lr, metrics],  # tb
                                                epochs=hyperparams.epochs, 
                                                steps_per_epoch=hyperparams.steps_per_epoch, 
                                                verbose=verbose)
            self.history.append(fit_output.history)

            model_forecast = self.models[i].forecast(train_dataset)
            self.save_forecast(forecast=model_forecast, filename=filename)

# %%
def get_forecasts(path, filt):
    a = []
    for f in tqdm(glob(os.path.join(WORKING_PATH, path, filt))):
        df = np.load(f)
        a.append(df)
    return a


def get_ensemble(forecasts):
    return np.mean(np.stack(forecasts, axis=-1), axis=-1)


def get_metrics(preds, labels):
    metrics = {}
    metrics["smape"] = 100*smape(preds=preds, labels=labels).numpy()
    metrics["mape"] = 100*mape(preds=preds, labels=labels).numpy()
    pe = 100*(preds-labels)/labels
    metrics["pe_mean"] = np.mean(pe)
    metrics["pe_median"] = np.median(pe)
    return metrics


def get_stats(samples=10, ensemble_size=64, test_dataset=None, config_filt=None, path=None):
    files = glob(os.path.join(WORKING_PATH, path, filt))
    all_repeats = set([int(f.split(os.sep)[-1].split(";")[0].split("=")[-1]) for f in files])
    preds = np.array(get_forecasts(path=path, filt=config_filt+".npy"))

    metric_samples = []
    ensemble_samples = []
    for s in range(samples):
        ensemble_repeats = np.random.choice(list(all_repeats), size=ensemble_size, replace=False)
        ensemble = preds[ensemble_repeats].mean(axis=0)
        metric_samples.append(get_metrics(preds=ensemble, labels=test_dataset.ts_raw))
        ensemble_samples.append(ensemble)

    return pd.DataFrame(metric_samples), ensemble_samples


def save_ensemble_files(path, ensembles):
    pathlib.Path(f"{WORKING_PATH}/{path}").mkdir(parents=True, exist_ok=True)
    for i, e in enumerate(ensembles):
        filename = os.path.join(path, f"{i}.csv")
        df = pd.DataFrame(data=e, columns=[f"V{i+1}" for i in range(12)], index=[f"P{i+1}" for i in range(35)])
        df.to_csv(filename)

# %%
if __name__ == "__main__":
    PROJECT_ROOT = os.getcwd()
    DATASETS_PATH = os.path.join(PROJECT_ROOT, "data")
    WORKING_PATH = PROJECT_ROOT
    LOGDIR = os.path.join(WORKING_PATH, "logs")
    MODEL_VERSION = 'Enhanced_NBEATS'

    os.makedirs(DATASETS_PATH, exist_ok=True)
    os.makedirs(LOGDIR, exist_ok=True)

    print(f"Project Root: {PROJECT_ROOT}")
    print(f"Datasets Path: {DATASETS_PATH}")
    print(f"Logs Directory: {LOGDIR}")
    print(f"Model Version: {MODEL_VERSION}")

    train_dataset = ElectricityLoader(path='data', split='train')
    test_dataset = ElectricityLoader(path='data', split='test')

    trainer = Trainer(hyperparams=hyperparams, logdir=LOGDIR)
    trainer.fit(train_dataset=train_dataset, test_dataset=test_dataset)

    split = 0
    path = f"results/{MODEL_VERSION}_split{split}/"
    filt = "*repeat=*;steps_per_epoch=100*block_layers=3*loss=pnmse*pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight*"

    forecasts = get_forecasts(path, filt)
    a = get_ensemble(forecasts)
    print("SMAPE:", 100 * smape(preds=a, labels=test_dataset.ts_raw).numpy())
    print("MAPE:", 100 * mape(preds=a, labels=test_dataset.ts_raw).numpy())
    print("RMSE:", rmse(preds=a, labels=test_dataset.ts_raw).numpy())

    ensemble_size = 64

    metrics_pnmse, ensembles_pnmse = get_stats(samples=100, ensemble_size=ensemble_size, 
                                               path=f"results/{MODEL_VERSION}_split{split}/", 
                                               test_dataset=test_dataset,
                                               config_filt=filt)

    print(f"PNMSE(MAPE) loss bootstrap stats, ensemble of {ensemble_size} sampled without replacement from 1024 models")
    print(metrics_pnmse.describe(percentiles=[0.05, 0.25, 0.5, 0.75, 0.95]))

    path = f"results/{MODEL_VERSION}_split{hyperparams.split}/ensemble_{filt}"
    save_ensemble_files(path=path, ensembles=ensembles_pnmse)
# Out:
# Project Root: /home/aeris/Final
# Datasets Path: /home/aeris/Final/data
# Logs Directory: /home/aeris/Final/logs
# Model Version: Enhanced_NBEATS
# Fitting model 1 out of 1024, repeat=0;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 2 out of 1024, repeat=1;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 3 out of 1024, repeat=2;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 4 out of 1024, repeat=3;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 5 out of 1024, repeat=4;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 6 out of 1024, repeat=5;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 7 out of 1024, repeat=6;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 8 out of 1024, repeat=7;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 9 out of 1024, repeat=8;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 10 out of 1024, repeat=9;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 11 out of 1024, repeat=10;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 12 out of 1024, repeat=11;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 13 out of 1024, repeat=12;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 14 out of 1024, repeat=13;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 15 out of 1024, repeat=14;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 16 out of 1024, repeat=15;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 17 out of 1024, repeat=16;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 18 out of 1024, repeat=17;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 19 out of 1024, repeat=18;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 20 out of 1024, repeat=19;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 21 out of 1024, repeat=20;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 22 out of 1024, repeat=21;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 23 out of 1024, repeat=22;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 24 out of 1024, repeat=23;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 25 out of 1024, repeat=24;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 26 out of 1024, repeat=25;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 27 out of 1024, repeat=26;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 28 out of 1024, repeat=27;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 29 out of 1024, repeat=28;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 30 out of 1024, repeat=29;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 31 out of 1024, repeat=30;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 32 out of 1024, repeat=31;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 33 out of 1024, repeat=32;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 34 out of 1024, repeat=33;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 35 out of 1024, repeat=34;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 36 out of 1024, repeat=35;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 37 out of 1024, repeat=36;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 38 out of 1024, repeat=37;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 39 out of 1024, repeat=38;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 40 out of 1024, repeat=39;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 41 out of 1024, repeat=40;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 42 out of 1024, repeat=41;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 43 out of 1024, repeat=42;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 44 out of 1024, repeat=43;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 45 out of 1024, repeat=44;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 46 out of 1024, repeat=45;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 47 out of 1024, repeat=46;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 48 out of 1024, repeat=47;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 49 out of 1024, repeat=48;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 50 out of 1024, repeat=49;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 51 out of 1024, repeat=50;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 52 out of 1024, repeat=51;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 53 out of 1024, repeat=52;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 54 out of 1024, repeat=53;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 55 out of 1024, repeat=54;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 56 out of 1024, repeat=55;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 57 out of 1024, repeat=56;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 58 out of 1024, repeat=57;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 59 out of 1024, repeat=58;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 60 out of 1024, repeat=59;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 61 out of 1024, repeat=60;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 62 out of 1024, repeat=61;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 63 out of 1024, repeat=62;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 64 out of 1024, repeat=63;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 65 out of 1024, repeat=64;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 66 out of 1024, repeat=65;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 67 out of 1024, repeat=66;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 68 out of 1024, repeat=67;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 69 out of 1024, repeat=68;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 70 out of 1024, repeat=69;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 71 out of 1024, repeat=70;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 72 out of 1024, repeat=71;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 73 out of 1024, repeat=72;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 74 out of 1024, repeat=73;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 75 out of 1024, repeat=74;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 76 out of 1024, repeat=75;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 77 out of 1024, repeat=76;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 78 out of 1024, repeat=77;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 79 out of 1024, repeat=78;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 80 out of 1024, repeat=79;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 81 out of 1024, repeat=80;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 82 out of 1024, repeat=81;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 83 out of 1024, repeat=82;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 84 out of 1024, repeat=83;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 85 out of 1024, repeat=84;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 86 out of 1024, repeat=85;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 87 out of 1024, repeat=86;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 88 out of 1024, repeat=87;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 89 out of 1024, repeat=88;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 90 out of 1024, repeat=89;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 91 out of 1024, repeat=90;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 92 out of 1024, repeat=91;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 93 out of 1024, repeat=92;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 94 out of 1024, repeat=93;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 95 out of 1024, repeat=94;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 96 out of 1024, repeat=95;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 97 out of 1024, repeat=96;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 98 out of 1024, repeat=97;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 99 out of 1024, repeat=98;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 100 out of 1024, repeat=99;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 101 out of 1024, repeat=100;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 102 out of 1024, repeat=101;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 103 out of 1024, repeat=102;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 104 out of 1024, repeat=103;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 105 out of 1024, repeat=104;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 106 out of 1024, repeat=105;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 107 out of 1024, repeat=106;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 108 out of 1024, repeat=107;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 109 out of 1024, repeat=108;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 110 out of 1024, repeat=109;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 111 out of 1024, repeat=110;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 112 out of 1024, repeat=111;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 113 out of 1024, repeat=112;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 114 out of 1024, repeat=113;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 115 out of 1024, repeat=114;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 116 out of 1024, repeat=115;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 117 out of 1024, repeat=116;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 118 out of 1024, repeat=117;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 119 out of 1024, repeat=118;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 120 out of 1024, repeat=119;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 121 out of 1024, repeat=120;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 122 out of 1024, repeat=121;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 123 out of 1024, repeat=122;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 124 out of 1024, repeat=123;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 125 out of 1024, repeat=124;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 126 out of 1024, repeat=125;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 127 out of 1024, repeat=126;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 128 out of 1024, repeat=127;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 129 out of 1024, repeat=128;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 130 out of 1024, repeat=129;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 131 out of 1024, repeat=130;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 132 out of 1024, repeat=131;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 133 out of 1024, repeat=132;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 134 out of 1024, repeat=133;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 135 out of 1024, repeat=134;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 136 out of 1024, repeat=135;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 137 out of 1024, repeat=136;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 138 out of 1024, repeat=137;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 139 out of 1024, repeat=138;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 140 out of 1024, repeat=139;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 141 out of 1024, repeat=140;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 142 out of 1024, repeat=141;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 143 out of 1024, repeat=142;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 144 out of 1024, repeat=143;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 145 out of 1024, repeat=144;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 146 out of 1024, repeat=145;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 147 out of 1024, repeat=146;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 148 out of 1024, repeat=147;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 149 out of 1024, repeat=148;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 150 out of 1024, repeat=149;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 151 out of 1024, repeat=150;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 152 out of 1024, repeat=151;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 153 out of 1024, repeat=152;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 154 out of 1024, repeat=153;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 155 out of 1024, repeat=154;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 156 out of 1024, repeat=155;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 157 out of 1024, repeat=156;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 158 out of 1024, repeat=157;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 159 out of 1024, repeat=158;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 160 out of 1024, repeat=159;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 161 out of 1024, repeat=160;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 162 out of 1024, repeat=161;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 163 out of 1024, repeat=162;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 164 out of 1024, repeat=163;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 165 out of 1024, repeat=164;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 166 out of 1024, repeat=165;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 167 out of 1024, repeat=166;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 168 out of 1024, repeat=167;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 169 out of 1024, repeat=168;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 170 out of 1024, repeat=169;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 171 out of 1024, repeat=170;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 172 out of 1024, repeat=171;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 173 out of 1024, repeat=172;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 174 out of 1024, repeat=173;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 175 out of 1024, repeat=174;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 176 out of 1024, repeat=175;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 177 out of 1024, repeat=176;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 178 out of 1024, repeat=177;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 179 out of 1024, repeat=178;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 180 out of 1024, repeat=179;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 181 out of 1024, repeat=180;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 182 out of 1024, repeat=181;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 183 out of 1024, repeat=182;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 184 out of 1024, repeat=183;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 185 out of 1024, repeat=184;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 186 out of 1024, repeat=185;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 187 out of 1024, repeat=186;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 188 out of 1024, repeat=187;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 189 out of 1024, repeat=188;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 190 out of 1024, repeat=189;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 191 out of 1024, repeat=190;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 192 out of 1024, repeat=191;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 193 out of 1024, repeat=192;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 194 out of 1024, repeat=193;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 195 out of 1024, repeat=194;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 196 out of 1024, repeat=195;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 197 out of 1024, repeat=196;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 198 out of 1024, repeat=197;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 199 out of 1024, repeat=198;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 200 out of 1024, repeat=199;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 201 out of 1024, repeat=200;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 202 out of 1024, repeat=201;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 203 out of 1024, repeat=202;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 204 out of 1024, repeat=203;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 205 out of 1024, repeat=204;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 206 out of 1024, repeat=205;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 207 out of 1024, repeat=206;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 208 out of 1024, repeat=207;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 209 out of 1024, repeat=208;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 210 out of 1024, repeat=209;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 211 out of 1024, repeat=210;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 212 out of 1024, repeat=211;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 213 out of 1024, repeat=212;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 214 out of 1024, repeat=213;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 215 out of 1024, repeat=214;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 216 out of 1024, repeat=215;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 217 out of 1024, repeat=216;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 218 out of 1024, repeat=217;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 219 out of 1024, repeat=218;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 220 out of 1024, repeat=219;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 221 out of 1024, repeat=220;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 222 out of 1024, repeat=221;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 223 out of 1024, repeat=222;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 224 out of 1024, repeat=223;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 225 out of 1024, repeat=224;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 226 out of 1024, repeat=225;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 227 out of 1024, repeat=226;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 228 out of 1024, repeat=227;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 229 out of 1024, repeat=228;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 230 out of 1024, repeat=229;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 231 out of 1024, repeat=230;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 232 out of 1024, repeat=231;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 233 out of 1024, repeat=232;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 234 out of 1024, repeat=233;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 235 out of 1024, repeat=234;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 236 out of 1024, repeat=235;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 237 out of 1024, repeat=236;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 238 out of 1024, repeat=237;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 239 out of 1024, repeat=238;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 240 out of 1024, repeat=239;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 241 out of 1024, repeat=240;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 242 out of 1024, repeat=241;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 243 out of 1024, repeat=242;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 244 out of 1024, repeat=243;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 245 out of 1024, repeat=244;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 246 out of 1024, repeat=245;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 247 out of 1024, repeat=246;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 248 out of 1024, repeat=247;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 249 out of 1024, repeat=248;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 250 out of 1024, repeat=249;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 251 out of 1024, repeat=250;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 252 out of 1024, repeat=251;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 253 out of 1024, repeat=252;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 254 out of 1024, repeat=253;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 255 out of 1024, repeat=254;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 256 out of 1024, repeat=255;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 257 out of 1024, repeat=256;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 258 out of 1024, repeat=257;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 259 out of 1024, repeat=258;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 260 out of 1024, repeat=259;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 261 out of 1024, repeat=260;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 262 out of 1024, repeat=261;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 263 out of 1024, repeat=262;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 264 out of 1024, repeat=263;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 265 out of 1024, repeat=264;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 266 out of 1024, repeat=265;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 267 out of 1024, repeat=266;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 268 out of 1024, repeat=267;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 269 out of 1024, repeat=268;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 270 out of 1024, repeat=269;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 271 out of 1024, repeat=270;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 272 out of 1024, repeat=271;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 273 out of 1024, repeat=272;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 274 out of 1024, repeat=273;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 275 out of 1024, repeat=274;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 276 out of 1024, repeat=275;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 277 out of 1024, repeat=276;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 278 out of 1024, repeat=277;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 279 out of 1024, repeat=278;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 280 out of 1024, repeat=279;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 281 out of 1024, repeat=280;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 282 out of 1024, repeat=281;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 283 out of 1024, repeat=282;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 284 out of 1024, repeat=283;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 285 out of 1024, repeat=284;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 286 out of 1024, repeat=285;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 287 out of 1024, repeat=286;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 288 out of 1024, repeat=287;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 289 out of 1024, repeat=288;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 290 out of 1024, repeat=289;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 291 out of 1024, repeat=290;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 292 out of 1024, repeat=291;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 293 out of 1024, repeat=292;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 294 out of 1024, repeat=293;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# ...
# Fitting model 934 out of 1024, repeat=933;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 935 out of 1024, repeat=934;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 936 out of 1024, repeat=935;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 937 out of 1024, repeat=936;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 938 out of 1024, repeat=937;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 939 out of 1024, repeat=938;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 940 out of 1024, repeat=939;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 941 out of 1024, repeat=940;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 942 out of 1024, repeat=941;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 943 out of 1024, repeat=942;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 944 out of 1024, repeat=943;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 945 out of 1024, repeat=944;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 946 out of 1024, repeat=945;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 947 out of 1024, repeat=946;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 948 out of 1024, repeat=947;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 949 out of 1024, repeat=948;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 950 out of 1024, repeat=949;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 951 out of 1024, repeat=950;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 952 out of 1024, repeat=951;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 953 out of 1024, repeat=952;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 954 out of 1024, repeat=953;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 955 out of 1024, repeat=954;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 956 out of 1024, repeat=955;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 957 out of 1024, repeat=956;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 958 out of 1024, repeat=957;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 959 out of 1024, repeat=958;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 960 out of 1024, repeat=959;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 961 out of 1024, repeat=960;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 962 out of 1024, repeat=961;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 963 out of 1024, repeat=962;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 964 out of 1024, repeat=963;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 965 out of 1024, repeat=964;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 966 out of 1024, repeat=965;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 967 out of 1024, repeat=966;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 968 out of 1024, repeat=967;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 969 out of 1024, repeat=968;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 970 out of 1024, repeat=969;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 971 out of 1024, repeat=970;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 972 out of 1024, repeat=971;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 973 out of 1024, repeat=972;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 974 out of 1024, repeat=973;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 975 out of 1024, repeat=974;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 976 out of 1024, repeat=975;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 977 out of 1024, repeat=976;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 978 out of 1024, repeat=977;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 979 out of 1024, repeat=978;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 980 out of 1024, repeat=979;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 981 out of 1024, repeat=980;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 982 out of 1024, repeat=981;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 983 out of 1024, repeat=982;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 984 out of 1024, repeat=983;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 985 out of 1024, repeat=984;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 986 out of 1024, repeat=985;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 987 out of 1024, repeat=986;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 988 out of 1024, repeat=987;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 989 out of 1024, repeat=988;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 990 out of 1024, repeat=989;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 991 out of 1024, repeat=990;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 992 out of 1024, repeat=991;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 993 out of 1024, repeat=992;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 994 out of 1024, repeat=993;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 995 out of 1024, repeat=994;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 996 out of 1024, repeat=995;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 997 out of 1024, repeat=996;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 998 out of 1024, repeat=997;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 999 out of 1024, repeat=998;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 1000 out of 1024, repeat=999;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 1001 out of 1024, repeat=1000;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 1002 out of 1024, repeat=1001;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 1003 out of 1024, repeat=1002;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 1004 out of 1024, repeat=1003;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 1005 out of 1024, repeat=1004;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 1006 out of 1024, repeat=1005;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 1007 out of 1024, repeat=1006;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 1008 out of 1024, repeat=1007;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 1009 out of 1024, repeat=1008;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 1010 out of 1024, repeat=1009;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 1011 out of 1024, repeat=1010;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 1012 out of 1024, repeat=1011;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 1013 out of 1024, repeat=1012;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 1014 out of 1024, repeat=1013;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 1015 out of 1024, repeat=1014;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 1016 out of 1024, repeat=1015;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 1017 out of 1024, repeat=1016;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 1018 out of 1024, repeat=1017;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 1019 out of 1024, repeat=1018;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 1020 out of 1024, repeat=1019;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 1021 out of 1024, repeat=1020;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 1022 out of 1024, repeat=1021;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 1023 out of 1024, repeat=1022;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# Fitting model 1024 out of 1024, repeat=1023;steps_per_epoch=100;block_layers=3;loss=pnmse;pinball_tau=0.35;nmse_weight=0.35;pnmse_weights=mape;ts_sampling=ts_weight
# 100%|█████████████████████████████████████████████████████████████████████████████| 1024/1024 [00:00<00:00, 8069.91it/s]
# SMAPE: 3.4977909177541733
# MAPE: 3.421401232481003
# RMSE: 303.99985
# 100%|████████████████████████████████████████████████████████████████████████████| 1024/1024 [00:00<00:00, 43279.03it/s]
# PNMSE(MAPE) loss bootstrap stats, ensemble of 64 sampled without replacement from 1024 models
#             smape        mape     pe_mean   pe_median
# count  100.000000  100.000000  100.000000  100.000000
# mean     3.524106    3.447664   -0.575070   -0.076714
# std      0.043439    0.032293    0.117054    0.052203
# min      3.448971    3.386695   -0.876058   -0.283696
# 5%       3.462191    3.396183   -0.763341   -0.162105
# 25%      3.491903    3.427433   -0.672586   -0.099194
# 50%      3.521208    3.446854   -0.570352   -0.072628
# 75%      3.548922    3.467173   -0.478404   -0.047017
# 95%      3.595310    3.496977   -0.402131    0.007844
# max      3.725731    3.568993   -0.306153    0.036943
